# %%
import Bio
import Bio.PDB
import Bio.SeqRecord

# %%
pdbparser = Bio.PDB.PDBParser(QUIET=True)
structure = pdbparser.get_structure('PDB_1.pdb', 'PDB_1.pdb')

# %%
structure.get_atoms()
# Out:
# <generator object Structure.get_atoms at 0x7fb6eaafa430>

# %%
for model in structure:
    for chain in model:
        for residue in chain:
            for atom in residue:
                print(atom)
# Out:
# <Atom O4>
# <Atom C4>
# <Atom C3>
# <Atom O3>
# <Atom C2>
# <Atom O2>
# <Atom C1>
# <Atom O1>
# <Atom O5>
# <Atom C5>
# <Atom C6>
# <Atom O6>
# <Atom H4>
# <Atom H3>
# <Atom H3O>
# <Atom H2>
# <Atom H2O>
# <Atom H1>
# <Atom H1O>
# <Atom H5>
# <Atom H6>
# <Atom H61>
# <Atom H6O>
# <Atom O3>
# <Atom C3>
# <Atom C2>
# <Atom O2>
# <Atom C1>
# <Atom O5>
# <Atom C5>
# <Atom C6>
# <Atom O6>
# <Atom C4>
# <Atom O4>
# <Atom H3>
# <Atom H2>
# <Atom H2O>
# <Atom H1>
# <Atom H5>
# <Atom H6>
# <Atom H61>
# <Atom H6O>
# <Atom H4>
# <Atom H4O>
# <Atom N2>
# <Atom C2>
# <Atom C1>
# <Atom O5>
# <Atom C5>
# <Atom C6>
# <Atom O6>
# <Atom C4>
# <Atom O4>
# <Atom C3>
# <Atom O3>
# <Atom H2N>
# <Atom H2>
# <Atom H1>
# <Atom H5>
# <Atom H6>
# <Atom H61>
# <Atom H6O>
# <Atom H4>
# <Atom H3>
# <Atom C21>
# <Atom C11>
# <Atom O1>
# <Atom H21>
# <Atom H22>
# <Atom H23>
# <Atom C1>
# <Atom O5>
# <Atom C5>
# <Atom C6>
# <Atom O6>
# <Atom C4>
# <Atom O4>
# <Atom C3>
# <Atom O3>
# <Atom C2>
# <Atom O2>
# <Atom H1>
# <Atom H5>
# <Atom H6>
# <Atom H61>
# <Atom H6O>
# <Atom H4>
# <Atom H4O>
# <Atom H3>
# <Atom H3O>
# <Atom H2>
# <Atom H2O>
# <Atom C1>
# <Atom O5>
# <Atom C5>
# <Atom C6>
# <Atom C4>
# <Atom O4>
# <Atom C3>
# <Atom O3>
# <Atom C2>
# <Atom O2>
# <Atom H1>
# <Atom H5>
# <Atom H6>
# <Atom H61>
# <Atom H62>
# <Atom H4>
# <Atom H4O>
# <Atom H3>
# <Atom H3O>
# <Atom H2>
# <Atom H2O>

# %%
for atom in structure.get_atoms():
    print(atom)
# Out:
# <Atom O4>
# <Atom C4>
# <Atom C3>
# <Atom O3>
# <Atom C2>
# <Atom O2>
# <Atom C1>
# <Atom O1>
# <Atom O5>
# <Atom C5>
# <Atom C6>
# <Atom O6>
# <Atom H4>
# <Atom H3>
# <Atom H3O>
# <Atom H2>
# <Atom H2O>
# <Atom H1>
# <Atom H1O>
# <Atom H5>
# <Atom H6>
# <Atom H61>
# <Atom H6O>
# <Atom O3>
# <Atom C3>
# <Atom C2>
# <Atom O2>
# <Atom C1>
# <Atom O5>
# <Atom C5>
# <Atom C6>
# <Atom O6>
# <Atom C4>
# <Atom O4>
# <Atom H3>
# <Atom H2>
# <Atom H2O>
# <Atom H1>
# <Atom H5>
# <Atom H6>
# <Atom H61>
# <Atom H6O>
# <Atom H4>
# <Atom H4O>
# <Atom N2>
# <Atom C2>
# <Atom C1>
# <Atom O5>
# <Atom C5>
# <Atom C6>
# <Atom O6>
# <Atom C4>
# <Atom O4>
# <Atom C3>
# <Atom O3>
# <Atom H2N>
# <Atom H2>
# <Atom H1>
# <Atom H5>
# <Atom H6>
# <Atom H61>
# <Atom H6O>
# <Atom H4>
# <Atom H3>
# <Atom C21>
# <Atom C11>
# <Atom O1>
# <Atom H21>
# <Atom H22>
# <Atom H23>
# <Atom C1>
# <Atom O5>
# <Atom C5>
# <Atom C6>
# <Atom O6>
# <Atom C4>
# <Atom O4>
# <Atom C3>
# <Atom O3>
# <Atom C2>
# <Atom O2>
# <Atom H1>
# <Atom H5>
# <Atom H6>
# <Atom H61>
# <Atom H6O>
# <Atom H4>
# <Atom H4O>
# <Atom H3>
# <Atom H3O>
# <Atom H2>
# <Atom H2O>
# <Atom C1>
# <Atom O5>
# <Atom C5>
# <Atom C6>
# <Atom C4>
# <Atom O4>
# <Atom C3>
# <Atom O3>
# <Atom C2>
# <Atom O2>
# <Atom H1>
# <Atom H5>
# <Atom H6>
# <Atom H61>
# <Atom H62>
# <Atom H4>
# <Atom H4O>
# <Atom H3>
# <Atom H3O>
# <Atom H2>
# <Atom H2O>

# %%
for residue in model.get_residues():
    print(residue)
# Out:
# <Residue GLC het=H_GLC resseq=1 icode= >
# <Residue GAL het=H_GAL resseq=2 icode= >
# <Residue NBG het=H_NBG resseq=3 icode= >
# <Residue GAL het=H_GAL resseq=4 icode= >
# <Residue FUC het=H_FUC resseq=5 icode= >

# %%
structure.header
# Out:
# {'name': '',
#  'head': '',
#  'idcode': '',
#  'deposition_date': '1909-01-08',
#  'release_date': '1909-01-08',
#  'structure_method': 'unknown',
#  'resolution': None,
#  'structure_reference': [],
#  'journal_reference': '',
#  'author': '',
#  'compound': {'1': {'misc': 'alfucp(1-3)[bdgalp(1-4),ac(1-2)]bdglcpn(1-3)bdgalp(1-4)adglcp '}},
#  'source': {'1': {'misc': ''}},
#  'has_missing_residues': False,
#  'missing_residues': []}

# %%
model = structure[0]
chain = model["A"]

# %%
atoms = structure.get_atoms()
residues = structure.get_residues()

# %%
for residue in model.get_residues():
    print(residue)
# Out:
# <Residue GLC het=H_GLC resseq=1 icode= >
# <Residue GAL het=H_GAL resseq=2 icode= >
# <Residue NBG het=H_NBG resseq=3 icode= >
# <Residue GAL het=H_GAL resseq=4 icode= >
# <Residue FUC het=H_FUC resseq=5 icode= >

# %%
residue.get_parent()
# Out:
# <Chain id=A>

# %%
from biopandas.pdb import PandasPdb

# %%
ppdb_df =  PandasPdb().read_pdb('PDB.pdb')

# %%
ppdb_df.df['ATOM']
# Out:
# Empty DataFrame
# Columns: [record_name, atom_number, blank_1, atom_name, alt_loc, residue_name, blank_2, chain_id, residue_number, insertion, blank_3, x_coord, y_coord, z_coord, occupancy, b_factor, blank_4, segment_id, element_symbol, charge, line_idx]
# Index: []
#
# [0 rows x 21 columns]

# %%
ppdb_df.df['HETATM']
# Out:
#     record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        HETATM            1                O4                  GLC
# 1        HETATM            2                C4                  GLC
# 2        HETATM            3                C3                  GLC
# 3        HETATM            4                O3                  GLC
# 4        HETATM            5                C2                  GLC
# ..          ...          ...     ...       ...     ...          ...     ...
# 108      HETATM          109               H4O                  FUC
# 109      HETATM          110                H3                  FUC
# 110      HETATM          111               H3O                  FUC
# 111      HETATM          112                H2                  FUC
# 112      HETATM          113               H2O                  FUC
#
#     chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0          A               1            ...  -3.092    6.038   -6.409
# 1          A               1            ...  -3.044    5.852   -4.986
# 2          A               1            ...  -3.230    7.186   -4.252
# 3          A               1            ...  -2.116    8.067   -4.478
# 4          A               1            ...  -3.366    6.966   -2.746
# ..       ...             ...       ...  ...     ...      ...      ...
# 108        A               5            ...   5.340   -2.238  -11.331
# 109        A               5            ...   4.674    0.412  -13.355
# 110        A               5            ...   3.934   -2.139  -13.471
# 111        A               5            ...   2.676   -1.237  -11.746
# 112        A               5            ...   2.570    0.167  -14.192
#
#      occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0          1.0       0.0                                  O    NaN         2
# 1          1.0       0.0                                  C    NaN         3
# 2          1.0       0.0                                  C    NaN         4
# 3          1.0       0.0                                  O    NaN         5
# 4          1.0       0.0                                  C    NaN         6
# ..         ...       ...      ...        ...            ...    ...       ...
# 108        1.0       0.0                                  H    NaN       110
# 109        1.0       0.0                                  H    NaN       111
# 110        1.0       0.0                                  H    NaN       112
# 111        1.0       0.0                                  H    NaN       113
# 112        1.0       0.0                                  H    NaN       114
#
# [113 rows x 21 columns]
